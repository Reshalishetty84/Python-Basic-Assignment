# %% [markdown]
# 1)What is the difference between enclosing a list comprehension in square brackets and parentheses?
#
# The difference between enclosing a list comprehension in square brackets and parentheses is that the List comprehension is enclosed in square brackets [] while the Generator expression is enclosed in plain parentheses ().
#
# Example:l = [n*2 for n in range(1000)] # List comprehension
#
# g = (n*2 for n in range(1000))  # Generator expression

# %% [markdown]
# 2)What is the relationship between generators and iterators?
#
# GENERATORS:a)Function is used to implement a generator.
#
# b)All the local variables before the yield function are stored.
#
# c)Generators are mostly used in loops to generate an iterator by returning all the values in the loop without affecting the iteration of the loop
#
# d)Generator uses yield keyword
#
# e)Every generator is an iterator
#
# ITERATORS:a)Class is used to implement an iterator
#
# b)Local Variables aren’t used here.
#
# c)Iterators are used mostly to iterate or convert other objects to an iterator using iter() function.
#
# d)Iterator uses iter() and next() functions
#
# e)Every iterator is not a generator.

# %% [markdown]
# 3)What are the signs that a function is a generator function?
#
# If a function contains at least one yield statement (it may contain other yield or return statements), it becomes a generator function. Both yield and return will return some value from a function.

# %% [markdown]
# 4)What is the purpose of a yield statement?
#
# yield in Python can be used like the return statement in a function. When done so, the function instead of returning the output, it returns a generator that can be iterated upon. You can then iterate through the generator to extract items.

# %% [markdown]
# 5)What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.
#
# Map VS List Comprehension
# a)List comprehension is more concise and easier to read as compared to map.
#
# b)List comprehension allows filtering. In map, we have no such facility. For example, to print all even numbers in range of 100, we can write [n for n in range(100) if n%2 == 0]. There is no alternate for it in map
#
# c)List comprehension are used when a list of results is required as map only returns a map object and does not return any list.
#
# d)List comprehension is faster than map when we need to evaluate expressions that are too long or complicated to express
#
# e)Map is faster in case of calling an already defined function (as no lambda is required).
#
# MAP FUNCTION:
# The map function takes an Expression and an Iterable. The output will be an Iterable object where the expression will work on each element of the given Iterable. The output of each expression will be an element of the resultant Iterable.
#
# Syntax:map( expression, iterable)
#
# Parameters:It accepts two parameters as arguments the "expression maps "and  "iterable".
#
# expression- It is the formula you need to calculate the result.
# Iterable- It is the iterable whose each element will be calculated on from the expression.
#
# LIST COMPREHENSION:
# Python List Comprehension is used for creating a list where each element is generated by applying a simple formula on the given list.
#
# Syntax:esultant_list = [ <variable_expression> for <variable> in <input_list> ] or resultant_list = [ <variable_expression> for <variable> in <input_list> if <condition> ]
#
# Parameters:It takes two argument including a list.
#
# variable_expression- It is the formula containing a variable and the formula is used on the variable.
# variable- It is a variable to access each element.
# input_list- It is the given list from where each element will be accessed as variable and applied on the formula.
# condition- After calculating the expression, if it matches the given Cindy, then only it will appear in the resultant_list.
